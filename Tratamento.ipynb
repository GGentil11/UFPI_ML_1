# %%
import pandas as pd

df = pd.read_csv('dados_filtrados.csv')
display(df)
# Out:
#                  Series_Title Released_Year Certificate  \
# 0    The Shawshank Redemption          1994           A
# 1               The Godfather          1972           A
# 2             The Dark Knight          2008          UA
# 3      The Godfather: Part II          1974           A
# 4                12 Angry Men          1957           U
# ..                        ...           ...         ...
# 995    Breakfast at Tiffany's          1961           A
# 996                     Giant          1956           G
# 997     From Here to Eternity          1953      Passed
# 998                  Lifeboat          1944         NaN
# 999              The 39 Steps          1935         NaN
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ...

# %%
df.fillna({'Certificate': 'Dado faltante'}, inplace=True)
display(df)
# Out:
#                  Series_Title Released_Year    Certificate  \
# 0    The Shawshank Redemption          1994              A
# 1               The Godfather          1972              A
# 2             The Dark Knight          2008             UA
# 3      The Godfather: Part II          1974              A
# 4                12 Angry Men          1957              U
# ..                        ...           ...            ...
# 995    Breakfast at Tiffany's          1961              A
# 996                     Giant          1956              G
# 997     From Here to Eternity          1953         Passed
# 998                  Lifeboat          1944  Dado faltante
# 999              The 39 Steps          1935  Dado faltante
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# ...

# %%
def fill_missing_meta_score(row):
    if pd.isnull(row['Meta_score']):
        return row['IMDB_Rating'] * 10  # Converter a escala do IMDB_Rating para a escala do Meta_score (que é de 0 a 100)
    else:
        return row['Meta_score']

# %%
df['Meta_score'] = df.apply(fill_missing_meta_score, axis=1)

print(df.isnull().sum())

df.to_csv('dados_tratados.csv', index=False)
# Out:
# Series_Title     0
# Released_Year    0
# Certificate      0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# dtype: int64
